# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.21.5

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\primo\Desktop\Cours et Projets\Power BI\Population mondiale\population-growth-rates.xlsx")
print (df)
# Out:
#             Entity Code    Year  \
# 0      Afghanistan  AFG  1950.0
# 1      Afghanistan  AFG  1951.0
# 2      Afghanistan  AFG  1952.0
# 3      Afghanistan  AFG  1953.0
# 4      Afghanistan  AFG  1954.0
# ...            ...  ...     ...
# 36895     Zimbabwe  ZWE  2095.0
# 36896     Zimbabwe  ZWE  2096.0
# 36897     Zimbabwe  ZWE  2097.0
# 36898     Zimbabwe  ZWE  2098.0
# 36899     Zimbabwe  ZWE  2099.0
#
#        Estimates, 1950 - 2020: Annually interpolated demographic indicators - Population growth rate (percentage)  \
# 0                                                  1.129
# 1                                                  1.172
# 2                                                  1.257
# 3                                                  1.339
# 4                                                  1.418
# ...                                                  ...
# 36895                                                NaN
# ...

# %%
#Recherche de valeurs qui sont nulles
import pandas as pd
df = pd.read_excel(r"C:\Users\primo\Desktop\Cours et Projets\Power BI\Population mondiale\population-growth-rates.xlsx")
print (df)
df.isnull()
# Out:
#             Entity Code    Year  \
# 0      Afghanistan  AFG  1950.0
# 1      Afghanistan  AFG  1951.0
# 2      Afghanistan  AFG  1952.0
# 3      Afghanistan  AFG  1953.0
# 4      Afghanistan  AFG  1954.0
# ...            ...  ...     ...
# 36895     Zimbabwe  ZWE  2095.0
# 36896     Zimbabwe  ZWE  2096.0
# 36897     Zimbabwe  ZWE  2097.0
# 36898     Zimbabwe  ZWE  2098.0
# 36899     Zimbabwe  ZWE  2099.0
#
#        Estimates, 1950 - 2020: Annually interpolated demographic indicators - Population growth rate (percentage)  \
# 0                                                  1.129
# 1                                                  1.172
# 2                                                  1.257
# 3                                                  1.339
# 4                                                  1.418
# ...                                                  ...
# 36895                                                NaN
# ...

# %%
#Recherche de valeurs qui ne sont pas nulles
import pandas as pd
df = pd.read_excel(r"C:\Users\primo\Desktop\Cours et Projets\Power BI\Population mondiale\population-growth-rates.xlsx")
print (df)
df.notnull()
# Out:
#             Entity Code    Year  \
# 0      Afghanistan  AFG  1950.0
# 1      Afghanistan  AFG  1951.0
# 2      Afghanistan  AFG  1952.0
# 3      Afghanistan  AFG  1953.0
# 4      Afghanistan  AFG  1954.0
# ...            ...  ...     ...
# 36895     Zimbabwe  ZWE  2095.0
# 36896     Zimbabwe  ZWE  2096.0
# 36897     Zimbabwe  ZWE  2097.0
# 36898     Zimbabwe  ZWE  2098.0
# 36899     Zimbabwe  ZWE  2099.0
#
#        Estimates, 1950 - 2020: Annually interpolated demographic indicators - Population growth rate (percentage)  \
# 0                                                  1.129
# 1                                                  1.172
# 2                                                  1.257
# 3                                                  1.339
# 4                                                  1.418
# ...                                                  ...
# 36895                                                NaN
# ...

# %%
#Recherche de doublons
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36895    False
# 36896    False
# 36897    False
# 36898    False
# 36899    False
# Length: 36900, dtype: bool

# %%
#Description du Data
df.describe()
# Out:
#                Year  \
# count  36300.000000
# mean    2024.500000
# std       43.300904
# min     1950.000000
# 25%     1987.000000
# 50%     2024.500000
# 75%     2062.000000
# max     2099.000000
#
#        Estimates, 1950 - 2020: Annually interpolated demographic indicators - Population growth rate (percentage)  \
# count                                       17782.000000
# mean                                           70.080565
# std                                           365.321337
# min                                            -7.099000
# 25%                                             0.928250
# 50%                                             1.901000
# 75%                                             2.700750
# max                                          2099.000000
#
#        Medium fertility variant, 2020 - 2099: Annually interpolated demographic indicators - Population growth rate (percentage)  \
# count                                       19644.000000
# ...

# %%
#Recherche sum null
df.isnull().sum()
# Out:
# Entity                                                                                                                           0
# Code                                                                                                                          5850
# Year                                                                                                                           600
# Estimates, 1950 - 2020: Annually interpolated demographic indicators - Population growth rate (percentage)                   19118
# Medium fertility variant, 2020 - 2099: Annually interpolated demographic indicators - Population growth rate (percentage)    17256
# Unnamed: 5                                                                                                                   36580
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36900 entries, 0 to 36899
# Data columns (total 6 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Entity                                                                                                                     36900 non-null  object
#  1   Code                                                                                                                       36900 non-null  object
#  2   Year                                                                                                                       36300 non-null  float64
# ...
